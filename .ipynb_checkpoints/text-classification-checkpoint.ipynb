# %%
import numpy as np
import pandas as pd
# import matplotlib
# matplotlib.use('Agg')
import matplotlib.pyplot as plt 
import itertools
import utils
import os
from sklearn.utils import shuffle
from model import model,predict_model,stats
from store import store

# %%
pkl_hnd = store(static)

data = utils.file_parser(os.path.join('uploads',"data.txt"))
features = utils.feature_extractor(data['text'],5000)
sh = data.shape

# Preprocessing features and labels
data_x = utils.preprocess_features(features,2500)
data_y,enc = utils.label_encoder(data['label'],False,None)
pkl_hnd.dump(enc,'enc') 								# storing encoder


# # Splitting data into training set and validation set 
# train_x,train_y,valid_x,valid_y= utils.train_valid(data_x,data_y,0.2)

# #Balancing data with SMOTE
# data_n =utils.balance_data(train_x,train_y)
# # Selecting model and tuning hyperparameters
# tr =model(clf,data_n['text'][:sh[0]],data_n['label'][:sh[0]],valid_x,valid_y)
# pr = predict_model(valid_x)
# comb_mod = tr.model_selection()

# # Fitting model and predicting
# mod = tr.build_model(comb_mod)
# pkl_hnd.dump(mod ,'model')  							   # storing the model
# pred = pr.predict_model(model)

# #Training Statistics
# st = stats(pred,valid_y)
# acc,f1 =st.train_stats()

# #Plotting histogram and confusion matrix
# pkl_hnd.plot_hist(data['label'],hist_n)
# n_labels = np.unique(np.asarray(data['label']))
# pkl_hnd.dump(n_labels,'n_labels')							# storing labels
# cnf_matrix = st.cnf_mtx()
# pkl_hnd.plot_confusion_matrix(self,cnf_matrix, n_labels,cnmt_n,
#                           normalize=False,
#                           title='Confusion matrix',
#                           cmap=plt.cm.Blues,)

# %%
data
# Out:
#           label                                               text
# 6467  Not rated  Chhotu Restaurant 1.0 New Delhi North Indian 3...
# 7516       Good  Caf Knosh - The Leela Ambience Convention Hote...
# 4808  Not rated    The Muffin Girl 1.0 New Delhi Bakery 400.0 1.0
# 2774    Average  The Kathis 1.0 New Delhi Fast Food, North Indi...
# 2810    Average      Food Point 1.0 New Delhi Fast Food 200.0 1.0
# 6701  Very Good  AMPM Caf & Bar 1.0 New Delhi Continental, Ital...
# 1588    Average                  A1 1.0 Gurgaon Biryani 200.0 1.0
# 3297    Average  Pizza Hut 1.0 New Delhi Italian, Pizza, Fast F...
# 714     Average    Naivedya 1.0 Aurangabad North Indian 500.0 2.0
# 5736  Not rated  Do Bhai Paneer Wale And Sweets 1.0 New Delhi B...
# 4156    Average  Chicken Mughlai 1.0 New Delhi North Indian, Mu...
# 234     Average  Prairie Grille at SteepleGate Inn 216.0 Davenp...
# 8152    Average  Zaika Hindustani 1.0 Noida Mughlai, North Indi...
# 1932    Average        Cafeteria Point 1.0 Gurgaon Cafe 500.0 2.0
# 7710    Average  Tribe 1.0 New Delhi Continental, Seafood, Nort...
# 6712  Very Good  Pirates of Grill 1.0 New Delhi North Indian, C...
# 4574    Average  New Frontier Hotel 1.0 New Delhi North Indian ...
# 6698       Good  Wok In The Clouds 1.0 New Delhi Chinese, Thai,...
# 8371  Not rated            Cheese Pizza 1.0 Noida Pizza 250.0 1.0
# 1201       Good  Mosaic - Country Inn & Suites 1.0 Gurgaon Nort...
